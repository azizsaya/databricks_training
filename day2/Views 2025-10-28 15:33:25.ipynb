# %%
# %sql
create table dev.aziz.vendor_demo (id int) location 's3://jpmctraining/tables/naval/vendor'

# %%
# %sql
create view dev.aziz.avg_bal as 
select account_type, round(avg(available_balance)) as avg_bal from dev.aziz.account_json_parsed group by account_type
