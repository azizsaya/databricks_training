-- %%
%python
from pyspark.sql.functions import *

-- %%
%python
input_path="s3://jpmctraining/input_files"

-- %%
%python
def add_ingestion_col(df):
    return df.withColumn("ingestion_date",current_timestamp())

-- %%
use catalog dev;
--create schema if not exists dev.aziz_bronze;
--create schema if not exists dev.aziz_silver;
--create schema if not exists dev.aziz_gold;
